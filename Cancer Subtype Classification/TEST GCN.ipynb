# %% [markdown]
# <center><h1>Breast Cancer (<em>TCGA-BRCA</em>) Subtype Classification</h1></center></br>

# %% [markdown]
# </br><h4>Data Preprocessing:</h4>

# %%
# %run 1_Preprocess_TCGA_BRCA.ipynb
preprocessed_df = getPreprocessedData()
# Out:
# Original TCGA-BRCA Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Columns: 1941 entries, rs_CLEC3A to histological.type
# dtypes: float64(827), int64(1110), object(4)
# memory usage: 10.4+ MB
#
# No of Missing Values-Feature Dataset: 389
#
#  Missing values of Feature Dataset:
#  rs_CLEC3A              0
# rs_CPB1                0
# rs_SCGB2A2             0
# rs_SCGB1D2             0
# rs_TFF1                0
#                     ...
# vital.status           0
# PR.Status            122
# ER.Status            122
# HER2.Final.Status    145
# histological.type      0
# Length: 1941, dtype: int64
#
# No of Missing Values - Feature Dataset: 0
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 560 entries, 0 to 649
# Columns: 1941 entries, rs_CLEC3A to histological.type
# dtypes: float64(827), int64(1110), object(4)
# memory usage: 8.3+ MB
# Unique values in ER.Status:
# ['Positive' 'Negative' 'Performed but Not Available' 'Indeterminate'
#  'Not Performed']
#
# Unique values in PR.Status:
# ['Positive' 'Negative' 'Performed but Not Available' 'Indeterminate'
#  'Not Performed']
#
# Unique values in HER2.Final.Status:
# ['Negative' 'Positive' 'Equivocal' 'Not Available']
#
# Uncommon values (not Positive/Negative) in ER.Status: 31
# Uncommon values (not Positive/Negative) in PR.Status: 34
# Uncommon values (not Positive/Negative) in HER2.Final.Status: 17
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 0 to 649
# Columns: 1941 entries, rs_CLEC3A to histological.type
# dtypes: float64(827), int64(1110), object(4)
# memory usage: 7.6+ MB
#
# Encoded Values to Histological Type Mapping:
#
# 0  -->  infiltrating ductal carcinoma
# 1  -->  infiltrating lobular carcinoma
#
# Encoded Values to PR Status Mapping:
#
# 0  -->  Negative
# 1  -->  Positive
# 2  -->  Unknown
#
# Multi-Omics:  {'mu', 'pp', 'rs', 'cn'}
# Subtypes:  {'Basal-Like', 'HER2-Enriched', 'Undefined', 'Luminal-B', 'Luminal-A'}
# Status:  {'vital.status', 'histological.type', 'PR.Status', 'ER.Status', 'HER2.Final.Status'}
#
# Subtype Labled TCGA-BRCA Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 0 to 649
# Columns: 1946 entries, rs_CLEC3A to Luminal-A
# dtypes: float64(827), int32(2), int64(1117)
# memory usage: 7.6 MB
#
# Gene Records Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 0 to 649
# Columns: 604 entries, rs_CLEC3A to rs_HEPN1
# dtypes: float64(604)
# memory usage: 2.4 MB
#
# Protein Records Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 0 to 649
# Columns: 223 entries, pp_X14.3.3.beta to pp_p90RSK.pT359.S363
# dtypes: float64(223)
# memory usage: 912.2 KB
#
# Copy Number Variation(CNV) Records Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 0 to 649
# Columns: 860 entries, cn_ISG15 to cn_MLC1
# dtypes: int64(860)
# memory usage: 3.4 MB
#
# Mutation Records Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 0 to 649
# Columns: 249 entries, mu_ANK3 to mu_PEG3
# dtypes: int64(249)
# memory usage: 1016.2 KB
#
# Sample count per subtype:
#  Basal-Like        90
# HER2-Enriched     25
# Undefined         62
# Luminal-B         56
# Luminal-A        279
# dtype: int64

# %% [markdown]
# </br><h4>Hetrograph Construction:</h4>

# %%
# %run 2_TCGA_BRCA_Heterograph_Construction.ipynb
hetrograph = construct_hetrograph(preprocessed_df, top_k = None)
# Out:
# C:\Users\dular\.conda\envs\meditech_env\lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# C:\Users\dular\.conda\envs\meditech_env\lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# Creating deterministic biological mappings...
# Creating deterministic subtype mappings...
#
# Mapping summary:
#     gene: 604 nodes
#     protein: 223 nodes
#     cnv: 860 nodes
#     mutation: 249 nodes
#     subtype: 5 nodes
#     case: 512 nodes
#
# Saving biological mappings to files...
#     Main mappings saved to: graph_mappings\biological_mappings.json
#     Individual mappings saved to: graph_mappings/
#     Reverse mappings saved to: graph_mappings\reverse_biological_mappings.json
#
# Defining Case and Subtype Nodes...
# Defining Multi-Omic Nodes...
#
# Defining Multi-Omics - Pateint Relations...
# 	Defining "Gene in Case" Metapath...
# 	Defining "Protein in Case" Metapath...
# 	Defining "CNV in Case" Metapath...
# 	Defining "Mutation in Case" Metapath...
# 	Defining "Case has Gene" Metapath...
# 	Defining "Case has Protein" Metapath...
# 	Defining "Case has CNV" Metapath...
# 	Defining "Case has Mutation" Metapath...
#
# Defining Patient - Patient Similarity Edges...
# 	Defining "Case Similar to Case" Metapath...
# 	Defining "Case Coexpress Case" Metapath...
# 	Defining "Gene in Case" Metapath...
#
# Defining Intra-Omic Feature Networks...
# 	Defining "Gene Interacts Gene" Metapath...
# 	Defining "Protein Interacts Protein" Metapath...
# 	Defining "CNV Co-CNV CNV" Metapath...
# 	Defining "Mutation Co-Mutation Mutation" Metapath...
#
# Defining Cross-Omic Bridges...
# 	Defining "Gene Encodes Protein" Metapath...
# 	Defining "Mutation in Gene" Metapath...
# 	Defining "CNV affects Gene" Metapath...
#
# Defining Subtype Anchor Nodes Relations...
# 	Defining "Case has Subtype" Metapath...
# 	Defining "Subtype Characterized by Gene" Metapath...
# 	Defining "Subtype Characterized by Protein" Metapath...
# 	Defining "Subtype Characterized by CNV" Metapath...
# 	Defining "Subtype Characterized by Mutation" Metapath...
#
#  HeteroData(
#   case={
#     x=[512, 1941],
#     y=[512],
#   },
#   subtype={ x=[5, 5] },
#   gene={ x=[604, 1] },
#   protein={ x=[223, 1] },
#   cnv={ x=[860, 1] },
#   mutation={ x=[249, 1] },
#   (gene, in, case)={ edge_index=[2, 283172] },
#   (protein, in, case)={ edge_index=[2, 113915] },
#   (cnv, in, case)={ edge_index=[2, 228540] },
#   (mutation, in, case)={ edge_index=[2, 4125] },
#   (case, has, gene)={ edge_index=[2, 283172] },
#   (case, has, protein)={ edge_index=[2, 113915] },
#   (case, has, cnv)={ edge_index=[2, 228540] },
#   (case, has, mutation)={ edge_index=[2, 4125] },
#   (case, similar_to, case)={ edge_index=[2, 111778] },
#   (case, coexpr_with, case)={ edge_index=[2, 261632] },
#   (gene, interacts, gene)={ edge_index=[2, 3698] },
#   (protein, ppi, protein)={ edge_index=[2, 66] },
#   (cnv, co_cnv, cnv)={ edge_index=[2, 16530] },
#   (mutation, co_mutation, mutation)={ edge_index=[2, 0] },
#   (gene, encodes, protein)={ edge_index=[2, 2] },
#   (mutation, in_gene, gene)={ edge_index=[2, 14] },
#   (cnv, affects, gene)={ edge_index=[2, 262] },
#   (case, has_subtype, subtype)={ edge_index=[2, 512] },
#   (subtype, characterized_by, gene)={ edge_index=[2, 604] },
#   (subtype, characterized_by, protein)={ edge_index=[2, 223] },
#   (subtype, characterized_by, cnv)={ edge_index=[2, 860] },
#   (subtype, characterized_by, mutation)={ edge_index=[2, 249] }
# )
#
# Node sets: ['case', 'subtype', 'gene', 'protein', 'cnv', 'mutation']
#
# Edge sets: [('gene', 'in', 'case'), ('protein', 'in', 'case'), ('cnv', 'in', 'case'), ('mutation', 'in', 'case'), ('case', 'has', 'gene'), ('case', 'has', 'protein'), ('case', 'has', 'cnv'), ('case', 'has', 'mutation'), ('case', 'similar_to', 'case'), ('case', 'coexpr_with', 'case'), ('gene', 'interacts', 'gene'), ('protein', 'ppi', 'protein'), ('cnv', 'co_cnv', 'cnv'), ('mutation', 'co_mutation', 'mutation'), ('gene', 'encodes', 'protein'), ('mutation', 'in_gene', 'gene'), ('cnv', 'affects', 'gene'), ('case', 'has_subtype', 'subtype'), ('subtype', 'characterized_by', 'gene'), ('subtype', 'characterized_by', 'protein'), ('subtype', 'characterized_by', 'cnv'), ('subtype', 'characterized_by', 'mutation')]

# %%
# %run ./HAN_Model/GCN.ipynb
main(hetrograph)
# Out:
# WARNING:tensorflow:From C:\Users\dular\AppData\Local\Temp\ipykernel_16948\523533447.py:26: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From C:\Users\dular\.conda\envs\meditech_env\lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ================================================================================
# GCN CANCER SUBTYPE CLASSIFICATION EXPERIMENT
# ================================================================================
# → Found 35 meta-paths of length <= 3
#
# [1/35] Testing path: case--has-->gene -> gene--in-->case -> case--similar_to-->case
# WARNING:tensorflow:From C:\Users\dular\.conda\envs\meditech_env\lib\site-packages\tensorflow\python\util\dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\dular\AppData\Local\Temp\ipykernel_16948\523533447.py:279: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.1818 (trained in 2.75s)
#
# [2/35] Testing path: case--has-->gene -> gene--in-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 1.98s)
#
# [3/35] Testing path: case--has-->gene -> gene--interacts-->gene -> gene--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.17s)
#
# [4/35] Testing path: case--has-->gene -> gene--encodes-->protein -> protein--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 4.27s)
#
# [5/35] Testing path: case--has-->protein -> protein--in-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 1.75s)
#
# [6/35] Testing path: case--has-->protein -> protein--in-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 5.11s)
#
# [7/35] Testing path: case--has-->protein -> protein--ppi-->protein -> protein--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 1.11s)
#
# [8/35] Testing path: case--has-->cnv -> cnv--in-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 1.94s)
#
# [9/35] Testing path: case--has-->cnv -> cnv--in-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.46s)
#
# [10/35] Testing path: case--has-->cnv -> cnv--co_cnv-->cnv -> cnv--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 4.66s)
#
# [11/35] Testing path: case--has-->cnv -> cnv--affects-->gene -> gene--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.1818 (trained in 1.79s)
#
# [12/35] Testing path: case--has-->mutation -> mutation--in-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.10s)
#
# [13/35] Testing path: case--has-->mutation -> mutation--in-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.27s)
#
# [14/35] Testing path: case--has-->mutation -> mutation--co_mutation-->mutation -> mutation--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.6753 (trained in 3.35s)
#
# [15/35] Testing path: case--has-->mutation -> mutation--in_gene-->gene -> gene--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 1.46s)
#
# [16/35] Testing path: case--similar_to-->case -> case--has-->gene -> gene--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 3.56s)
#
# [17/35] Testing path: case--similar_to-->case -> case--has-->protein -> protein--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 3.21s)
#
# [18/35] Testing path: case--similar_to-->case -> case--has-->cnv -> cnv--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 7.84s)
#
# [19/35] Testing path: case--similar_to-->case -> case--has-->mutation -> mutation--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 3.59s)
#
# [20/35] Testing path: case--similar_to-->case -> case--similar_to-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 3.22s)
#
# [21/35] Testing path: case--similar_to-->case -> case--similar_to-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.1818 (trained in 2.30s)
#
# [22/35] Testing path: case--similar_to-->case -> case--coexpr_with-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 5.32s)
#
# [23/35] Testing path: case--similar_to-->case -> case--coexpr_with-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 3.19s)
#
# [24/35] Testing path: case--coexpr_with-->case -> case--has-->gene -> gene--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 6.96s)
#
# [25/35] Testing path: case--coexpr_with-->case -> case--has-->protein -> protein--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 1.94s)
#
# [26/35] Testing path: case--coexpr_with-->case -> case--has-->cnv -> cnv--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 6.33s)
#
# [27/35] Testing path: case--coexpr_with-->case -> case--has-->mutation -> mutation--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.1818 (trained in 1.45s)
#
# [28/35] Testing path: case--coexpr_with-->case -> case--similar_to-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.13s)
#
# [29/35] Testing path: case--coexpr_with-->case -> case--similar_to-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.40s)
#
# [30/35] Testing path: case--coexpr_with-->case -> case--coexpr_with-->case -> case--similar_to-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.20s)
#
# [31/35] Testing path: case--coexpr_with-->case -> case--coexpr_with-->case -> case--coexpr_with-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5455 (trained in 2.26s)
#
# [32/35] Testing path: case--has_subtype-->subtype -> subtype--characterized_by-->gene -> gene--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.2208 (trained in 1.40s)
#
# [33/35] Testing path: case--has_subtype-->subtype -> subtype--characterized_by-->protein -> protein--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.5325 (trained in 1.91s)
#
# [34/35] Testing path: case--has_subtype-->subtype -> subtype--characterized_by-->cnv -> cnv--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.1818 (trained in 1.81s)
#
# [35/35] Testing path: case--has_subtype-->subtype -> subtype--characterized_by-->mutation -> mutation--in-->case
# INFO:tensorflow:Restoring parameters from gcn_best.ckpt
#   ✓ Test accuracy: 0.2208 (trained in 3.16s)
#
# ================================================================================
# GCN EXPERIMENT RESULTS
# ================================================================================
#
# Top 10 Meta-paths:
#  1. Accuracy: 0.6753 | Path: case--has-->mutation -> mutation--co_mutation-->mutation -> mutation--in-->case
#  2. Accuracy: 0.5455 | Path: case--has-->gene -> gene--in-->case -> case--coexpr_with-->case
#  3. Accuracy: 0.5455 | Path: case--has-->gene -> gene--interacts-->gene -> gene--in-->case
#  4. Accuracy: 0.5455 | Path: case--has-->gene -> gene--encodes-->protein -> protein--in-->case
#  5. Accuracy: 0.5455 | Path: case--has-->protein -> protein--in-->case -> case--similar_to-->case
#  6. Accuracy: 0.5455 | Path: case--has-->protein -> protein--in-->case -> case--coexpr_with-->case
#  7. Accuracy: 0.5455 | Path: case--has-->protein -> protein--ppi-->protein -> protein--in-->case
#  8. Accuracy: 0.5455 | Path: case--has-->cnv -> cnv--in-->case -> case--similar_to-->case
#  9. Accuracy: 0.5455 | Path: case--has-->cnv -> cnv--in-->case -> case--coexpr_with-->case
# 10. Accuracy: 0.5455 | Path: case--has-->cnv -> cnv--co_cnv-->cnv -> cnv--in-->case
#
# 🏆 Best GCN result:
#    Accuracy: 0.6753
#    Meta-path: case--has-->mutation -> mutation--co_mutation-->mutation -> mutation--in-->case
# {'best_metapath': [('case', 'has', 'mutation'),
#   ('mutation', 'co_mutation', 'mutation'),
#   ('mutation', 'in', 'case')],
#  'best_accuracy': 0.6753246784210205,
#  'best_path_string': 'case--has-->mutation -> mutation--co_mutation-->mutation -> mutation--in-->case',
#  'all_results': [([('case', 'has', 'mutation'),
#     ('mutation', 'co_mutation', 'mutation'),
#     ('mutation', 'in', 'case')],
#    0.6753246784210205,
#    'case--has-->mutation -> mutation--co_mutation-->mutation -> mutation--in-->case'),
#   ([('case', 'has', 'gene'),
#     ('gene', 'in', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--has-->gene -> gene--in-->case -> case--coexpr_with-->case'),
#   ([('case', 'has', 'gene'),
#     ('gene', 'interacts', 'gene'),
#     ('gene', 'in', 'case')],
#    0.5454545021057129,
#    'case--has-->gene -> gene--interacts-->gene -> gene--in-->case'),
#   ([('case', 'has', 'gene'),
#     ('gene', 'encodes', 'protein'),
#     ('protein', 'in', 'case')],
#    0.5454545021057129,
#    'case--has-->gene -> gene--encodes-->protein -> protein--in-->case'),
#   ([('case', 'has', 'protein'),
#     ('protein', 'in', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--has-->protein -> protein--in-->case -> case--similar_to-->case'),
#   ([('case', 'has', 'protein'),
#     ('protein', 'in', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--has-->protein -> protein--in-->case -> case--coexpr_with-->case'),
#   ([('case', 'has', 'protein'),
#     ('protein', 'ppi', 'protein'),
#     ('protein', 'in', 'case')],
#    0.5454545021057129,
#    'case--has-->protein -> protein--ppi-->protein -> protein--in-->case'),
#   ([('case', 'has', 'cnv'),
#     ('cnv', 'in', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--has-->cnv -> cnv--in-->case -> case--similar_to-->case'),
#   ([('case', 'has', 'cnv'),
#     ('cnv', 'in', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--has-->cnv -> cnv--in-->case -> case--coexpr_with-->case'),
#   ([('case', 'has', 'cnv'), ('cnv', 'co_cnv', 'cnv'), ('cnv', 'in', 'case')],
#    0.5454545021057129,
#    'case--has-->cnv -> cnv--co_cnv-->cnv -> cnv--in-->case'),
#   ([('case', 'has', 'mutation'),
#     ('mutation', 'in', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--has-->mutation -> mutation--in-->case -> case--similar_to-->case'),
#   ([('case', 'has', 'mutation'),
#     ('mutation', 'in', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--has-->mutation -> mutation--in-->case -> case--coexpr_with-->case'),
#   ([('case', 'has', 'mutation'),
#     ('mutation', 'in_gene', 'gene'),
#     ('gene', 'in', 'case')],
#    0.5454545021057129,
#    'case--has-->mutation -> mutation--in_gene-->gene -> gene--in-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'has', 'gene'),
#     ('gene', 'in', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--has-->gene -> gene--in-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'has', 'protein'),
#     ('protein', 'in', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--has-->protein -> protein--in-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'has', 'cnv'),
#     ('cnv', 'in', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--has-->cnv -> cnv--in-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'has', 'mutation'),
#     ('mutation', 'in', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--has-->mutation -> mutation--in-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'similar_to', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--similar_to-->case -> case--similar_to-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'coexpr_with', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--coexpr_with-->case -> case--similar_to-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'coexpr_with', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--similar_to-->case -> case--coexpr_with-->case -> case--coexpr_with-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'has', 'gene'),
#     ('gene', 'in', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--has-->gene -> gene--in-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'has', 'protein'),
#     ('protein', 'in', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--has-->protein -> protein--in-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'has', 'cnv'),
#     ('cnv', 'in', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--has-->cnv -> cnv--in-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'similar_to', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--similar_to-->case -> case--similar_to-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'similar_to', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--similar_to-->case -> case--coexpr_with-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'coexpr_with', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--coexpr_with-->case -> case--similar_to-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'coexpr_with', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.5454545021057129,
#    'case--coexpr_with-->case -> case--coexpr_with-->case -> case--coexpr_with-->case'),
#   ([('case', 'has_subtype', 'subtype'),
#     ('subtype', 'characterized_by', 'protein'),
#     ('protein', 'in', 'case')],
#    0.5324674844741821,
#    'case--has_subtype-->subtype -> subtype--characterized_by-->protein -> protein--in-->case'),
#   ([('case', 'has_subtype', 'subtype'),
#     ('subtype', 'characterized_by', 'mutation'),
#     ('mutation', 'in', 'case')],
#    0.22077922523021698,
#    'case--has_subtype-->subtype -> subtype--characterized_by-->mutation -> mutation--in-->case'),
#   ([('case', 'has_subtype', 'subtype'),
#     ('subtype', 'characterized_by', 'gene'),
#     ('gene', 'in', 'case')],
#    0.2207792103290558,
#    'case--has_subtype-->subtype -> subtype--characterized_by-->gene -> gene--in-->case'),
#   ([('case', 'has', 'gene'),
#     ('gene', 'in', 'case'),
#     ('case', 'similar_to', 'case')],
#    0.1818181872367859,
#    'case--has-->gene -> gene--in-->case -> case--similar_to-->case'),
#   ([('case', 'has', 'cnv'),
#     ('cnv', 'affects', 'gene'),
#     ('gene', 'in', 'case')],
#    0.1818181872367859,
#    'case--has-->cnv -> cnv--affects-->gene -> gene--in-->case'),
#   ([('case', 'similar_to', 'case'),
#     ('case', 'similar_to', 'case'),
#     ('case', 'coexpr_with', 'case')],
#    0.1818181872367859,
#    'case--similar_to-->case -> case--similar_to-->case -> case--coexpr_with-->case'),
#   ([('case', 'coexpr_with', 'case'),
#     ('case', 'has', 'mutation'),
#     ('mutation', 'in', 'case')],
#    0.1818181872367859,
#    'case--coexpr_with-->case -> case--has-->mutation -> mutation--in-->case'),
#   ([('case', 'has_subtype', 'subtype'),
#     ('subtype', 'characterized_by', 'cnv'),
#     ('cnv', 'in', 'case')],
#    0.1818181872367859,
#    'case--has_subtype-->subtype -> subtype--characterized_by-->cnv -> cnv--in-->case')],
#  'model_type': 'GCN'}
